# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression
from math import ceil
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn import preprocessing
from sklearn.utils import shuffle

def error(y, a, b, X):
    return ((y-(a+np.dot(b,X)))[0])

def error2(y, a, b, X):
    return ((y-(a+np.dot(b,X)))[0])**2

def gd(a, b,lr, X, y, lam):
    bi=[]
    i=0
    er=error(y, a, b, X)
    for bk in b:
        bi.append(bk+X[i]*lr*(er)-lam*bk)
        i=i+1
    a=a+1*lr*(y-((a+(np.dot(b,X)))))
    return a, bi

def gdmb(a, b,lr, X, y, lam):
    bi=[]
    er=0
    i=0
    for x in X:
        er=er+error(y[i], a, b, x)/len(X)
        i=i+1
    i=0
    mean=np.mean(pd.DataFrame(X))
    for bk in b:
        bi.append(bk+mean[i]*lr*(er)-lam*bk)
        i=i+1
    a=a+1*lr*(er)
    return a, bi

# %%
d=pd.read_csv('https://raw.githubusercontent.com/ClaseML-2017/MaterialyTareas/master/datos/regLin.csv')

# %%
d[['X']]
# Out:
#               X
# 0     35.657897
# 1     48.685931
# 2     95.861773
# 3     25.997253
# 4     49.964772
# 5     55.003337
# 6     78.375881
# 7     15.286028
# 8     81.066092
# 9     35.059204
# 10    10.627199
# 11    67.484259
# 12    66.230640
# 13    57.957191
# 14    95.185536
# 15    77.219095
# 16    92.859492
# 17    67.223617
# 18    56.746339
# 19    34.735291
# 20    97.317591
# 21    38.591213
# 22    51.608742
# 23    59.781250
# 24    67.810553
# 25    12.199013
# 26    25.041432
# 27    27.765660
# 28    68.489203
# 29    15.216642
# ...         ...
# 999   87.577378
# 1000  82.166957
# 1001  34.656976
# 1002  58.941310
# 1003  78.875733
# 1004  59.029010
# 1005  97.149709
# 1006  98.433789
# 1007   2.459832
# 1008  13.227604
# 1009  74.039264
# 1010  19.903694
# 1011   9.963961
# 1012  17.743197
# 1013  91.421756
# 1014  55.388254
# 1015  81.563611
# 1016  67.634153
# 1017  61.210794
# 1018  60.426290
# 1019  20.828499
# 1020  13.607691
# 1021  86.939856
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(pd.DataFrame(d[['X']]), pd.DataFrame(d['y']), test_size=0.33, random_state=42)


normalizer = preprocessing.StandardScaler()
normalizer.fit(X_train)
X_train = pd.DataFrame(normalizer.transform(X_train))
X_test = pd.DataFrame(normalizer.transform(X_test))

normalizer.fit(y_train)
y_train = pd.DataFrame(normalizer.transform(y_train))
y_test = pd.DataFrame(normalizer.transform(y_test))

# %%
a2=500
b2=[500]
bs=50
lam=0.00
i=0
for j in range(1000):
    X_train, y_train=shuffle(X_train, y_train, random_state=j)
    print "\r"+str(j),
    for k in range(len(X_train)/bs):
        a2, b2=gdmb(a2, b2, 0.1, X_train.values[k*bs:(k+1)*bs], y_train.values[k*bs:(k+1)*bs], lam)
        i=i+1
te=0
for k in range(len(X_test.values)):
    te=te+error2(y_test.values[k], a2, b2,  X_test.values[k])/len(X_test.values)
    
print "\r With Lam=0.00 we got want a="+str(a2)+" and b="+str(b2)+" and error of "+str(te)
lam=0.01
i=0
for j in range(1000):
    X_train, y_train=shuffle(X_train, y_train, random_state=j)
    print "\r"+str(j),
    for k in range(len(X_train)/bs):
        a2, b2=gdmb(a2, b2, 0.1, X_train.values[k*bs:(k+1)*bs], y_train.values[k*bs:(k+1)*bs], lam)
        i=i+1
te=0
for k in range(len(X_test.values)):
    te=te+error2(y_test.values[k], a2, b2,  X_test.values[k])/len(X_test.values)
    
print "\r With Lam=0.01 we got want a="+str(a2)+" and b="+str(b2)+" and error of "+str(te)
# Out:
#  With Lam=0.00 we got want a=0.00358940435355 and b=[0.96867622500364492] and error of 0.0515050967642
#  With Lam=0.01 we got want a=0.00880950536662 and b=[0.15148639375615644] and error of 0.768955108059

# %%
a2=500
b2=[500]
bs=50
lam=0.00
i=0
for j in range(1000):
    print "\r"+str(j),
    for k in range(len(X_train)/bs):
        a2, b2=gd(a2, b2, 0.1, X_train.values[k], y_train.values[k], lam)
        i=i+1
te=0
for k in range(len(X_test.values)):
    te=te+error2(y_test.values[k], a2, b2,  X_test.values[k])/len(X_test.values)
    
print "\r With Lam=0.00 we got want a="+str(a2)+" and b="+str(b2)+" and error of "+str(te)
lam=0.01
i=0
for j in range(1000):
    print "\r"+str(j),
    for k in range(len(X_train)):
        a2, b2=gd(a2, b2, 0.1, X_train.values[k], y_train.values[k], lam)
        i=i+1
te=0
for k in range(len(X_test.values)):
    te=te+error2(y_test.values[k], a2, b2,  X_test.values[k])/len(X_test.values)
    
print "\r With Lam=0.01 we got want a="+str(a2)+" and b="+str(b2)+" and error of "+str(te)
# Out:
#  With Lam=0.00 we got want a=[ 0.08707659] and b=[0.88779537897061145] and error of 0.06324798947
#  With Lam=0.01 we got want a=[-0.13435946] and b=[1.0358349399741604] and error of 0.0777753428259

# %%
d=pd.read_csv('https://raw.githubusercontent.com/ClaseML-2017/MaterialyTareas/master/datos/regLinPoli.csv')

# %%
d[['X', 'X2', 'X3', 'X4', 'X5']]
# Out:
#               X           X2        X3        X4    X5
# 0      7.317938    53.552216  0.864389  0.859736   114
# 1      1.284357     1.649574  0.108686  0.959256   115
# 2     97.740652  9553.235089  1.990075 -0.344100   116
# 3     17.753591   315.190006  1.249286 -0.889370   117
# 4     66.441081  4414.417290  1.822437 -0.450777   118
# 5     40.916163  1674.132433  1.611895 -0.075387   119
# 6     95.687035  9156.008719  1.980853  0.991361   120
# 7     83.685262  7003.223054  1.922649  0.907687   121
# 8     39.873426  1589.890107  1.600684  0.823344   122
# 9     90.678945  8222.671039  1.957506  0.414362   123
# 10    54.888909  3012.792371  1.739485 -0.996045   124
# 11    76.622209  5870.962891  1.884355  0.940461   125
# 12    12.598322   158.717715  1.100313  0.031946   126
# 13    37.489483  1405.461344  1.573909 -0.208097   127
# 14    76.888739  5911.878127  1.885863  0.996779   128
# 15    35.291288  1245.475043  1.547668 -0.669674   129
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(pd.DataFrame(d[['X', 'X2', 'X3', 'X4', 'X5']]), pd.DataFrame(d['y']), test_size=0.33, random_state=42)


normalizer = preprocessing.StandardScaler()
normalizer.fit(X_train)
X_train = pd.DataFrame(normalizer.transform(X_train))
X_test = pd.DataFrame(normalizer.transform(X_test))

normalizer.fit(y_train)
y_train = pd.DataFrame(normalizer.transform(y_train))
y_test = pd.DataFrame(normalizer.transform(y_test))

# %%
a2=500
b2=[500, 500, 500, 500, 500]
bs=50
lam=0.00
i=0
for j in range(1000):
    X_train, y_train=shuffle(X_train, y_train, random_state=j)
    print "\r"+str(j),
    for k in range(len(X_train)/bs):
        a2, b2=gdmb(a2, b2, 0.1, X_train.values[k*bs:(k+1)*bs], y_train.values[k*bs:(k+1)*bs], lam)
        i=i+1
te=0
for k in range(len(X_test.values)):
    te=te+error2(y_test.values[k], a2, b2,  X_test.values[k])/len(X_test.values)
    
print "\r With Lam=0.00 we got want a="+str(a2)+" and b="+str(b2)+" and error of "+str(te)
lam=0.01
i=0
for j in range(1000):
    X_train, y_train=shuffle(X_train, y_train, random_state=j)
    print "\r"+str(j),
    for k in range(len(X_train)/bs):
        a2, b2=gdmb(a2, b2, 0.1, X_train.values[k*bs:(k+1)*bs], y_train.values[k*bs:(k+1)*bs], lam)
        i=i+1
te=0
for k in range(len(X_test.values)):
    te=te+error2(y_test.values[k], a2, b2,  X_test.values[k])/len(X_test.values)
    
print "\r With Lam=0.01 we got want a="+str(a2)+" and b="+str(b2)+" and error of "+str(te)
# Out:
#  With Lam=0.00 we got want a=-0.0219958591679 and b=[-12.030267768507121, 10.088158384136806, 3.7422790180253251, 0.11481255908767193, 0.13644553623003255] and error of 2.19651418253
#  With Lam=0.01 we got want a=-0.000844749643835 and b=[0.10711675331214898, 0.11575420268377989, 0.073379388484335797, 0.0042827019490521206, 0.0052583376787660096] and error of 0.51828954989

# %%
a2=500
b2=[500, 500, 500, 500, 500]
bs=50
lam=0.00
i=0
for j in range(1000):
    print "\r"+str(j),
    for k in range(len(X_train)/bs):
        a2, b2=gd(a2, b2, 0.1, X_train.values[k], y_train.values[k], lam)
        i=i+1
te=0
for k in range(len(X_test.values)):
    te=te+error2(y_test.values[k], a2, b2,  X_test.values[k])/len(X_test.values)
    
print "\r With Lam=0.00 we got want a="+str(a2)+" and b="+str(b2)+" and error of "+str(te)
lam=0.01
i=0
for j in range(1000):
    print "\r"+str(j),
    for k in range(len(X_train)):
        a2, b2=gd(a2, b2, 0.1, X_train.values[k], y_train.values[k], lam)
        i=i+1
te=0
for k in range(len(X_test.values)):
    te=te+error2(y_test.values[k], a2, b2,  X_test.values[k])/len(X_test.values)
    
print "\r With Lam=0.01 we got want a="+str(a2)+" and b="+str(b2)+" and error of "+str(te)
# Out:
#  With Lam=0.00 we got want a=[-0.86901381] and b=[-12.832729573783046, 8.2202832122800817, 8.0981240048577341, -0.50655663967544606, -0.062162830973619354] and error of 7.63815146301
#  With Lam=0.01 we got want a=[-0.01390857] and b=[0.37152686711301908, 0.59284826737443819, -0.01877370572839103, 0.017719476357061909, -0.023225076086110862] and error of 0.0111097031129
